# %%
import os 
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from PIL import Image
from sklearn.metrics import confusion_matrix

# %%
from keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout
from keras.models import Sequential
from keras.models import Sequential, Model

# %%
# ls

# %%
dataimg = ['./data/training/','./data/testing/']

image_directory = dataimg[0]
SIZE = 100
dataset = []  # Dataset  
label = []  # 0 chait : 1 knife

# %%
def create_dataset(img_folder,dataset_img,label_class):
    for img in tqdm(os.listdir(img_folder)):
   
        target = -1
        if img[:5] == 'chair':  
            #target = 'chair'
            target = 0
        
        if img[:5] == 'knife':
            #target = 'knife'
            target = 1
        if img[:8] == 'saucepan':
            #target = 'saucepan'
            target = 2
        if target != -1:
          
            try:
               
                image = cv2.imread(img_folder  + img)
                #image = image.astype('float32')
                image = Image.fromarray(image, 'RGB')
                image = image.resize((SIZE, SIZE))
                dataset_img.append(np.array(image))
                label_class.append(target)
           
            except Exception:
                pass

# %% [markdown]
# ### ARQUITECTURA DEL MODELO

# %%
INPUT_SHAPE = (SIZE, SIZE, 3)   #change to (SIZE, SIZE, 3)
inp = keras.layers.Input(shape=INPUT_SHAPE)

conv1 = keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same')(inp)
pool1 = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1)
norm1 = keras.layers.BatchNormalization(axis = -1)(pool1)
drop1 = keras.layers.Dropout(rate=0.2)(norm1)

conv2 = keras.layers.Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(drop1)
pool2 = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2)
norm2 = keras.layers.BatchNormalization(axis = -1)(pool2)
drop2 = keras.layers.Dropout(rate=0.2)(norm2)

flat = keras.layers.Flatten()(drop2)  #Flatten the matrix to get it ready for dense.

hidden1 = keras.layers.Dense(512, activation='relu')(flat)
norm3 = keras.layers.BatchNormalization(axis = -1)(hidden1)
drop3 = keras.layers.Dropout(rate=0.2)(norm3)
hidden2 = keras.layers.Dense(256, activation='relu')(drop3)
norm4 = keras.layers.BatchNormalization(axis = -1)(hidden2)
drop4 = keras.layers.Dropout(rate=0.2)(norm4)

out = keras.layers.Dense(3, activation='sigmoid')(drop4)
#------------------------------------------
model = keras.Model(inputs=inp, outputs=out)
#------------------------------------------
model.compile(optimizer='adam',
                loss='categorical_crossentropy',   #Check between binary_crossentropy and categorical_crossentropy
                metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 100, 100, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 25, 25, 32)        0
# ...

# %%
model = None
model = Sequential()
model.add(Convolution2D(32, (3, 3), input_shape = (SIZE, SIZE, 3), activation = 'relu', data_format='channels_last'))
model.add(MaxPooling2D(pool_size = (2, 2), data_format="channels_last"))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))
model.add(Convolution2D(32, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2), data_format="channels_last"))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(activation = 'relu', units=512))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))
model.add(Dense(activation = 'relu', units=256))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))
model.add(Dense(activation = 'sigmoid', units=3))
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 98, 98, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 49, 49, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 49, 49, 32)        128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 47, 47, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 23, 23, 32)        128
# ...

# %% [markdown]
# ### BASE DE DATOS

# %%
create_dataset(image_directory,dataset,label)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3820/3820 [00:55<00:00, 69.02it/s]

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset,to_categorical(np.array(label)), test_size = 0.30, random_state = 0)

# %% [markdown]
# ### ENTRENAMIENTO

# %%
history = model.fit(np.array(X_train),
                    y_train, 
                    batch_size = 64, 
                    verbose = 1, 
                    epochs = 15,  
                    validation_split = 0.1,
                    shuffle = False)
# Out:
# Epoch 1/15
# 76/76 [==============================] - 62s 702ms/step - loss: 0.8817 - accuracy: 0.7011 - val_loss: 2.4702 - val_accuracy: 0.6336
# Epoch 2/15
# 76/76 [==============================] - 53s 691ms/step - loss: 0.2125 - accuracy: 0.9192 - val_loss: 0.3857 - val_accuracy: 0.8617
# Epoch 3/15
# 76/76 [==============================] - 56s 732ms/step - loss: 0.0980 - accuracy: 0.9679 - val_loss: 0.3928 - val_accuracy: 0.8542
# Epoch 4/15
# 76/76 [==============================] - 57s 746ms/step - loss: 0.0523 - accuracy: 0.9836 - val_loss: 0.1356 - val_accuracy: 0.9477
# Epoch 5/15
# 76/76 [==============================] - 58s 758ms/step - loss: 0.0272 - accuracy: 0.9925 - val_loss: 0.2913 - val_accuracy: 0.9065
# Epoch 6/15
# 76/76 [==============================] - 54s 708ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.3450 - val_accuracy: 0.9028
# Epoch 7/15
# ...

# %% [markdown]
# ### RESULTADOS DE ENTRENAMEINTO

# %%
print("Test Accuracy: {:.2f}%".format(model.evaluate(np.array(X_test), np.array(y_test))[1]*100))
# Out:
# 72/72 [==============================] - 6s 76ms/step - loss: 0.5276 - accuracy: 0.8909
# Test Accuracy: 89.09%

# %%
plt.plot(history.history['val_loss'])
plt.plot(history.history['val_accuracy'])

# %%
prediction = model.predict(np.array(X_test))
y_test_matrix = [np.argmax(t) for t in y_test]
y_prediction_matrix = [np.argmax(t) for t in prediction]
confusion = confusion_matrix(y_test_matrix,y_prediction_matrix)

# %% [markdown]
# #### sigmoid

# %%
#Graficamos la matrix de confusion - [sigmoid]
sns.heatmap(confusion,annot=True,fmt="d",cbar=False)
plt.show()

# %% [markdown]
# #### softmax

# %%
#Graficamos la matrix de confusion - [softmax]
sns.heatmap(confusion,annot=True,fmt="d",cbar=False)
plt.show()

# %% [markdown]
# ### Guardamos el modelo

# %%
model.save('dataset_model.h5')

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 9813-5195
#
#  Directorio de C:\Users\k44sa\Documents\python\anaconda\Cuarta_entrega
#
# 11/03/2021  03:21 a.ÿm.    <DIR>          .
# 11/03/2021  03:21 a.ÿm.    <DIR>          ..
# 10/03/2021  08:59 a.ÿm.                19 .gitignore
# 10/03/2021  04:10 p.ÿm.    <DIR>          .ipynb_checkpoints
# 03/03/2021  02:01 p.ÿm.    <DIR>          .vscode
# 10/03/2021  07:08 p.ÿm.             7.876 BorderKnife.jpg
# 10/03/2021  08:56 a.ÿm.    <DIR>          codigos
# 09/03/2021  02:22 p.ÿm.    <DIR>          data
# 11/03/2021  03:21 a.ÿm.       105.835.440 dataset_model.h5
# 11/03/2021  03:20 a.ÿm.         1.416.582 main.ipynb
# 10/03/2021  08:56 a.ÿm.    <DIR>          modelo
# 10/03/2021  02:22 a.ÿm.             6.065 modelo_final.py
# 10/03/2021  06:00 p.ÿm.    <DIR>          procesamiento_img
#                5 archivos    107.265.982 bytes
#                8 dirs  359.760.932.864 bytes libres

# %% [markdown]
# ### PRUEBAS

# %%
k = 122
img = cv2.cvtColor(X_test[k],cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
pred_individual = model.predict(np.expand_dims(img,axis = 0));print(pred_individual);np.round(pred_individual,2)
# Out:
# [[7.7316014e-07 1.0110468e-04 1.0000000e+00]]
# array([[0., 0., 1.]], dtype=float32)

# %% [markdown]
# #### IMAGENES CON PROBLEMAS DE CLASIFICACION

# %% [markdown]
# ### Metodos

# %%
def showImg(img):
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    
def individualPrediction(img):
    pre_ind = model.predict(np.expand_dims(img,axis = 0))
 
    print(f'chair    : {pre_ind[0][0]}%')
    print(f'knife    : {pre_ind[0][1]}%')
    print(f'saucepan : {pre_ind[0][2]}%',end='\n\n')
    print(pre_ind)
    
def whiteBackground(img):
    img[np.where((img == [0,0,0]).all(axis=2))]=[255,255,255]
    plt.imshow(img)
    return img


def histogram_color(img,c):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    hist = cv2.calcHist([img],[c],None,[256],[0,256])
    plt.plot(hist)
    
def histogramAllColor(img):
    colors = ('b','g','r')
    for i,c in enumerate(colors):
        hist = cv2.calcHist([img],[i],None,[256],[0,256])
        plt.plot(hist,color=c)

# %% [markdown]
# ### Kernel's

# %%
def GrabCut(img, x_r,y_d,x_r2,y_d2):
    mask = np.zeros(img.shape[:2],np.uint8)
    bgdModel = np.zeros((1,65),np.float64)
    fgdModel = np.zeros((1,65),np.float64)

    rect = (x_r,y_d,x_r2,y_d2)
    cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

    mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
    img = img*mask2[:,:,np.newaxis]

    plt.imshow(img),plt.colorbar(),plt.show()
    
    return img

# %%
def Averaging(img,d):
    blur = cv2.blur(img,(d,d))
    
    plt.subplot(121),plt.imshow(img),plt.title('Original')
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
    plt.xticks([]), plt.yticks([])
    plt.show()
    return blur

# %%
def GaussianFiltering(img,d):
    try:
        blur = cv2.GaussianBlur(img,(d,d),0)
        plt.subplot(121),plt.imshow(img),plt.title('Original')
        plt.xticks([]), plt.yticks([])
        plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
        plt.xticks([]), plt.yticks([])
        plt.show()
        
        return blur
    except:
        print('la dimension del kernel debe ser con numeros impares')

# %%
def MedianFiltering(img,d):
    median = cv2.medianBlur(img,d)
    plt.subplot(121),plt.imshow(img),plt.title('Original')
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(median),plt.title('Blurred')
    plt.xticks([]), plt.yticks([])
    plt.show()
    return median

# %%
import glob

# %%
images = [cv2.imread(file) for file in tqdm(glob.glob("./data/imagenes/*.jpg"))]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 10.63it/s]

# %% [markdown]
# ### Problema #1

# %%
newImg = images[2]
showImg(newImg)

# %%
img_test = cv2.resize(newImg, (SIZE, SIZE))
showImg(img_test)
individualPrediction(img_test)
# Out:
# chair    : 0.9886391162872314%
# knife    : 0.9721883535385132%
# saucepan : 0.014255702495574951%
#
# [[0.9886391  0.97218835 0.0142557 ]]

# %%
# histogramAllColor(img_test)

# %%
# img_test[40][60]

# %%
img_test = GrabCut(img_test,3,15,65,60)

# %%
individualPrediction(img_test)
# Out:
# chair    : 0.9578045010566711%
# knife    : 0.9878734350204468%
# saucepan : 0.003763556480407715%
#
# [[0.9578045  0.98787344 0.00376356]]

# %%
img_av = Averaging(img_test,3)
individualPrediction(img_av)
# Out:
# chair    : 0.006940007209777832%
# knife    : 0.983259916305542%
# saucepan : 0.006019562482833862%
#
# [[0.00694001 0.9832599  0.00601956]]

# %%
# img_gus = GaussianFiltering(img_test,3)
# individualPrediction(img_gus)

# %%
# img_med = MedianFiltering(img_test,3)
# individualPrediction(img_med)

# %%
img_Bwhite = whiteBackground(img_test)
individualPrediction(img_Bwhite)
# Out:
# chair    : 0.029004186391830444%
# knife    : 0.999945878982544%
# saucepan : 0.009468406438827515%
#
# [[0.02900419 0.9999459  0.00946841]]

# %%
img_Bwhite_md = MedianFiltering(img_Bwhite,3)
individualPrediction(img_Bwhite_md)
# Out:
# chair    : 0.027297496795654297%
# knife    : 0.999945342540741%
# saucepan : 0.0166034996509552%
#
# [[0.0272975  0.99994534 0.0166035 ]]

# %% [markdown]
# ### Problema #2

# %%
def setColorImg(img,x_r,y_d,x_r2,y_d2,dim,val):
    img_set = img
    for i in range(y_d2):
        i+=y_d
        for j in range(x_r2):
            j+=x_r
            img_set[i,j,dim] = val
    return img_set

# %%
newImg_2 = images[4]
showImg(newImg_2)

# %%
img_test_2 = cv2.resize(newImg_2, (SIZE, SIZE))
showImg(img_test_2)
individualPrediction(img_test_2)
# Out:
# chair    : 0.3049471974372864%
# knife    : 0.8891522884368896%
# saucepan : 0.5480290055274963%
#
# [[0.3049472 0.8891523 0.548029 ]]

# %%
# for i in range(30):
#     i += 43
#     for j in range(10):
#         j+=35
#         img_test[i,j,0]=0

# %%
img_array = cv2.cvtColor(img_test_2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img_array,cmap='gray')

# %%
thr,imgB = cv2.threshold(img_array,150,255,cv2.THRESH_OTSU)

# %%
plt.imshow(imgB,cmap='gray')

# %%
individualPrediction(imgB)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 80, 80, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 80, 80, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 80, 80).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-418-66023e34f18b> in <module>
# ----> 1 individualPrediction(imgB)
#
# <ipython-input-358-d3837db14837> in individualPrediction(img)
#       3
#       4 def individualPrediction(img):
# ----> 5     pre_ind = model.predict(np.expand_dims(img,axis = 0))
#       6
#       7     print(f'chair    : {pre_ind[0][0]}%')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
# ...

# %%
histogramAllColor(img_test_2)

# %%
img_test_2[43,35,0]
# Out:
# 100

# %%
img_test_2[43,35,1]
# Out:
# 82

# %%
img_test_2[43,35,2]
# Out:
# 71

# %%
img_res = setColorImg(img_test,35,43,10,30,0,0)
img_res_2 = setColorImg(img_res,35,43,10,30,1,0)
img_res_3 = setColorImg(img_res_2,35,43,10,30,2,0)

# %%
img_res = setColorImg(img_test_2,35,43,10,30,2,50)

# %%
plt.imshow(img_res_3)

# %%
individualPrediction(img_res_3)
# Out:
# chair    : 0.8139800429344177%
# knife    : 0.9825180768966675%
# saucepan : 0.034380584955215454%
#
# [[0.81398004 0.9825181  0.03438058]]

# %%
# plt.imshow(img_res_3)

# %%
# img_test[43,35,0]

# %%
imggs = Averaging(img_res,2)

# %%
individualPrediction(imggs)
# Out:
# chair    : 0.9986401200294495%
# knife    : 0.23233598470687866%
# saucepan : 0.0324476957321167%
#
# [[0.9986401  0.23233598 0.0324477 ]]

# %%
img_rc = GrabCut(imggs,35,5,10,75)
# individualPrediction(img_rc)

# %%
img_rc = setColorImg(img_rc,35,43,10,30,0,100)

# %%
individualPrediction(img_rc)
# Out:
# chair    : 0.9967703819274902%
# knife    : 0.0018572509288787842%
# saucepan : 0.3559909164905548%
#
# [[0.9967704  0.00185725 0.35599092]]

# %%
img_Bwhite = whiteBackground(img_rc)
individualPrediction(img_Bwhite)
# Out:
# chair    : 0.988247275352478%
# knife    : 0.19544994831085205%
# saucepan : 0.014147013425827026%
#
# [[0.9882473  0.19544995 0.01414701]]

# %%
img01 = setColorImg(img_Bwhite,35,43,10,30,0,0)

# %%
img10 = GrabCut(img01,35,5,10,75)

# %%
individualPrediction(img10)
# Out:
# chair    : 0.9841030836105347%
# knife    : 0.027035951614379883%
# saucepan : 0.08185061812400818%
#
# [[0.9841031  0.02703595 0.08185062]]

# %%
img_Bwhite = whiteBackground(img10)
individualPrediction(img_Bwhite)
# Out:
# chair    : 0.9907149076461792%
# knife    : 0.04513758420944214%
# saucepan : 0.03929013013839722%
#
# [[0.9907149  0.04513758 0.03929013]]

# %%
img11 = setColorImg(img_Bwhite,35,43,10,30,100,0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-248-339cdf361133> in <module>
# ----> 1 img11 = setColorImg(img_Bwhite,35,43,10,30,100,0)
#
# <ipython-input-243-92e9e73486f7> in setColorImg(img, x_r, y_d, x_r2, y_d2, dim, val)
#       4         for j in range(x_r2):
#       5             j+=x_r
# ----> 6             img[i,j,dim] = val
#       7     return img
#       8
#
# IndexError: index 100 is out of bounds for axis 2 with size 3

# %%
plt.imshow(img01)

# %%
individualPrediction(img01)
# Out:
# chair    : 0.7488629817962646%
# knife    : 0.9973856210708618%
# saucepan : 0.013929784297943115%
#
# [[0.748863   0.9973856  0.01392978]]

# %%
edges = cv2.Canny(img_gus,100,200)

plt.subplot(121),plt.imshow(img_gus,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
newImg3 = images[4]
showImg(newImg3)

# %%
img_test = cv2.resize(newImg3, (SIZE, SIZE))
showImg(img_test)
individualPrediction(img_test)
# Out:
# chair    : 0.3049471974372864%
# knife    : 0.8891522884368896%
# saucepan : 0.5480290055274963%
#
# [[0.3049472 0.8891523 0.548029 ]]

# %%
img_gus = MedianFiltering(img_test,3)

# %%
# result = cv2.fastNlMeansDenoisingColored(img_test,None,20,20,70,25)
# showImg(result)

# %%
# individualPrediction(result)

# %%
img_test = GrabCut(img_gus,8,20,70,25)
individualPrediction(img_test)
# Out:
# chair    : 0.3747459053993225%
# knife    : 0.005114912986755371%
# saucepan : 0.9897748231887817%
#
# [[0.3747459  0.00511491 0.9897748 ]]

# %%
# img_Bwhite = whiteBackground(img_test)
# individualPrediction(img_Bwhite)

# %%
img = images[4]
Z = img.reshape((-1,3))

# convert to np.float32
Z = np.float32(Z)

# define criteria, number of clusters(K) and apply kmeans()
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 4
ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

# Now convert back into uint8, and make original image
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

cv2.imshow('res2',res2)
cv2.waitKey(0)
cv2.destroyAllWindows()
