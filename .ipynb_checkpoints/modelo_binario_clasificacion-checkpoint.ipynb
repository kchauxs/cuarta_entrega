# %%
import os
import cv2
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm import tqdm

from keras.utils import to_categorical
from keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout
from keras.models import Sequential

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import load_model

# %% [markdown]
# ### Principales metodos

# %%
def create_dataset(img_folder,dataset_img,label_class):
    
    for img in tqdm(os.listdir(img_folder)):

        target = -1
        if img[:5] == 'chair':  
            target = 0
        
        if img[:5] == 'knife':
            target = 1
            
        if img[:8] == 'saucepan':
            target = 2
            
        if target != -1:
            try:   
                #CARGAMOS LA IMAGEN
                image = cv2.imread(img_folder+img)
                
                #CAMBIAMOS EL FORMATO A RGB
                image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
                
                #CONVERTIOMS A ESCALA DE GRICES
                image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
                
                
                #SUAVIZAMOS LA IMAGEN
                blur = cv2.GaussianBlur(image,(5,5),0)
                #----------------------------------------------
                #UMBRAL BINARY - OTSU
                ret,image = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
             
                
                #UMBRAL - BINARY
                #ret,image = cv2.threshold(blur,127,255,cv2.THRESH_BINARY)
                
                #UMBRAL - TOZERO
                #ret,image = cv2.threshold(blur,127,255,cv2.THRESH_TOZERO)
                #----------------------------------------------
                
                #CAMBIAMOS EL TAMAÑO
                new_array = cv2.resize(image, (SIZE, SIZE)) 
                
                #AGREGAMOS AL DATASET
                dataset_img.append(new_array) 
                label_class.append(target)
            except Exception:
                pass

# %%
def histogramAllColor(img):
    colors = ('r','g','b')
    for i,c in enumerate(colors):
        hist = cv2.calcHist([img],[i],None,[256],[0,256])
        plt.plot(hist,color=c)
    plt.show()
        
        
def GrabCut(img_intput, x_r,y_d,x_r2,y_d2):
    img = img_intput
    mask = np.zeros(img.shape[:2],np.uint8)
    bgdModel = np.zeros((1,65),np.float64)
    fgdModel = np.zeros((1,65),np.float64)

    rect = (x_r,y_d,x_r2,y_d2)
    cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

    mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
    img = img*mask2[:,:,np.newaxis]

    plt.imshow(img),plt.colorbar(),plt.show()
    
    return img


def setColorImg(img,x_r,y_d,x_r2,y_d2,dim,val):
    img_set = img
    for i in range(y_d2):
        i+=y_d
        for j in range(x_r2):
            j+=x_r
            img_set[i,j,dim] = val
    return img_set

def whiteBackground(img_input):
    img = img_input
    img[np.where((img == [0,0,0]).all(axis=2))]=[255,255,255]
    plt.imshow(img)
    return img

def resShapeConv(img):
    img_res = img
    return np.array(img_res).reshape( SIZE, SIZE,1)

def predictImg(model_p,img):
    pred_individual = modelo_tr.predict(np.expand_dims(img,axis = 0))
    print(pred_individual)
    print(np.round(pred_individual,3))
    
def convertImageToGray(img):
    return cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    
def generateSize(img):
    return cv2.resize(img, (SIZE, SIZE)) 
  
def generateImageGray(img):
    ts_img = img
    ts_img = cv2.cvtColor(ts_img,cv2.COLOR_BGR2RGB)
    ts_img = convertImageToGray(ts_img)
    plt.imshow(ts_img,cmap='gray')
    plt.figure()
    ts_img = generateSize(ts_img)
    plt.imshow(ts_img,cmap='gray')
    #ts_img = resShapeConv(ts_img)
    
    return ts_img

def thGaussOtsu(img):
    blur = cv2.GaussianBlur(img,(5,5),0)
    _,th_img = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    return th_img

# %%
def showImg(img):
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    
def individualPrediction(model,img):
    pre_ind = model.predict(np.expand_dims(img,axis = 0))
 
    print(f'chair    : {pre_ind[0][0]}%')
    print(f'knife    : {pre_ind[0][1]}%')
    print(f'saucepan : {pre_ind[0][2]}%',end='\n\n')
    #print(pre_ind)
    
def histogram_color(img,c):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    hist = cv2.calcHist([img],[c],None,[256],[0,256])
    plt.plot(hist)
        
def Averaging(img,d):
    blur = cv2.blur(img,(d,d))
    
    plt.subplot(121),plt.imshow(img),plt.title('Original')
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
    plt.xticks([]), plt.yticks([])
    plt.show()
    return blur

def GaussianFiltering(img,d):
    try:
        blur = cv2.GaussianBlur(img,(d,d),0)
        plt.subplot(121),plt.imshow(img),plt.title('Original')
        plt.xticks([]), plt.yticks([])
        plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
        plt.xticks([]), plt.yticks([])
        plt.show()
        
        return blur
    except:
        print('la dimension del kernel debe ser con numeros impares')

def MedianFiltering(img,d):
    median = cv2.medianBlur(img,d)
    plt.subplot(121),plt.imshow(img),plt.title('Original')
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(median),plt.title('Blurred')
    plt.xticks([]), plt.yticks([])
    plt.show()
    return median

# %% [markdown]
# ####  Busqueda de las configuraciones de nuestro modelo

# %%
test_images = [cv2.imread(file) for file in tqdm(glob.glob("./data/testing_images/*.jpg"))]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 137.83it/s]

# %%
ts_img = test_images[1]
ts_img_rgb = cv2.cvtColor(ts_img,cv2.COLOR_BGR2RGB)
plt.imshow(ts_img_rgb)
plt.figure()
ts_img = convertImageToGray(ts_img_rgb)
plt.imshow(ts_img,cmap='gray')

# %%
histogramAllColor(ts_img_rgb)

# %% [markdown]
# #### Aplicacion de Umbrales simples

# %%
ret,thres_h1 = cv2.threshold(ts_img,127,255,cv2.THRESH_BINARY)
ret,thres_h2 = cv2.threshold(ts_img,127,255,cv2.THRESH_BINARY_INV)
ret,thres_h3 = cv2.threshold(ts_img,127,255,cv2.THRESH_TRUNC)
ret,thres_h4 = cv2.threshold(ts_img,127,255,cv2.THRESH_TOZERO)
ret,thres_h5 = cv2.threshold(ts_img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [ts_img, thres_h1, thres_h2, thres_h3, thres_h4, thres_h5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# #### Aplicacion la binarización de Otsu

# %%
ret1,th1 = cv2.threshold(ts_img,127,255,cv2.THRESH_BINARY)
ret2,th2 = cv2.threshold(ts_img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

blur = cv2.GaussianBlur(ts_img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
titles = ['Original Image','BINARY','BINARY and OTSU','GAUSS, BINARY and OTSU']
images = [ts_img, th1, th2, th3]

# %%
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %% [markdown]
# ## MODELO

# %%
dataimg = ['./data/training/','./data/testing/']
PATH = dataimg[0]
SIZE = 80
dataset = [] 
label = []

# %% [markdown]
# ### Base de datos

# %%
create_dataset(PATH,dataset,label)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3396/3396 [00:51<00:00, 65.62it/s]

# %%
df = np.array(dataset).reshape(-1, SIZE, SIZE)
df = df.reshape(df.shape[0], df.shape[1], df.shape[2], 1)

# %% [markdown]
# #### Datos de entrenamiento y prueba

# %%
X_train, X_test, y_train, y_test = train_test_split(df,to_categorical(np.array(label)), test_size = 0.25, random_state = 0)

# %% [markdown]
# ### Arquitecuta del modelo

# %%
model = Sequential()
model.add(Convolution2D(32, (3, 3),
                        input_shape=(SIZE,SIZE,1),
                        activation = 'relu',
                        data_format='channels_last'))
model.add(MaxPooling2D(pool_size = (2, 2),
                       data_format="channels_last"))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))

model.add(Convolution2D(32, (3, 3),
                        activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2),
                       data_format="channels_last"))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(activation = 'relu', units=512))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))

model.add(Dense(activation = 'relu', units=256))
model.add(BatchNormalization(axis = -1))
model.add(Dropout(0.2))

model.add(Dense(activation = 'sigmoid', units=3))
#model.add(Dense(activation = 'softmax', units=3))
model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 78, 78, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 39, 39, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 39, 39, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 39, 39, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 37, 37, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 18, 18, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10368)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               5308928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 5,453,923
# Trainable params: 5,452,259
# Non-trainable params: 1,664
# _________________________________________________________________
# None

# %% [markdown]
# ### Entrenamiento del modelo

# %%
history = model.fit(np.array(X_train),
                    y_train, 
                    batch_size = 64, 
                    verbose = 1, 
                    epochs = 15,  
                    validation_split = 0.1,
                    shuffle = False)
# Out:
# Epoch 1/15
# 36/36 [==============================] - 17s 448ms/step - loss: 0.8349 - accuracy: 0.7327 - val_loss: 2.5373 - val_accuracy: 0.6471
# Epoch 2/15
# 36/36 [==============================] - 15s 416ms/step - loss: 0.2496 - accuracy: 0.9015 - val_loss: 2.3591 - val_accuracy: 0.5490
# Epoch 3/15
# 36/36 [==============================] - 15s 404ms/step - loss: 0.0848 - accuracy: 0.9760 - val_loss: 0.8862 - val_accuracy: 0.7725
# Epoch 4/15
# 36/36 [==============================] - 17s 472ms/step - loss: 0.0338 - accuracy: 0.9952 - val_loss: 0.4866 - val_accuracy: 0.8627
# Epoch 5/15
# 36/36 [==============================] - 16s 433ms/step - loss: 0.0236 - accuracy: 0.9952 - val_loss: 0.4808 - val_accuracy: 0.8784
# Epoch 6/15
# 36/36 [==============================] - 15s 407ms/step - loss: 0.0125 - accuracy: 0.9986 - val_loss: 0.4161 - val_accuracy: 0.8745
# Epoch 7/15
# 36/36 [==============================] - 16s 444ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.8824
# Epoch 8/15
# 36/36 [==============================] - 17s 459ms/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 0.3549 - val_accuracy: 0.8706
# Epoch 9/15
# 36/36 [==============================] - 17s 465ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3612 - val_accuracy: 0.8784
# Epoch 10/15
# 36/36 [==============================] - 17s 476ms/step - loss: 0.0037 - accuracy: 0.9998 - val_loss: 0.4024 - val_accuracy: 0.8588
# Epoch 11/15
# 36/36 [==============================] - 15s 419ms/step - loss: 0.0035 - accuracy: 0.9999 - val_loss: 0.3741 - val_accuracy: 0.8863
# Epoch 12/15
# 36/36 [==============================] - 16s 455ms/step - loss: 0.0050 - accuracy: 0.9980 - val_loss: 0.3729 - val_accuracy: 0.8941
# Epoch 13/15
# 36/36 [==============================] - 15s 422ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.5396 - val_accuracy: 0.8863
# Epoch 14/15
# 36/36 [==============================] - 15s 403ms/step - loss: 0.0068 - accuracy: 0.9991 - val_loss: 0.4129 - val_accuracy: 0.8745
# Epoch 15/15
# 36/36 [==============================] - 16s 447ms/step - loss: 0.0130 - accuracy: 0.9979 - val_loss: 0.4384 - val_accuracy: 0.8784

# %% [markdown]
# ### Resultados del modelo

# %%
print("Test Accuracy: {:.2f}%".format(model.evaluate(np.array(X_test), np.array(y_test))[1]*100))
# Out:
# 27/27 [==============================] - 1s 53ms/step - loss: 0.5848 - accuracy: 0.8539
# Test Accuracy: 85.39%

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])

# %%
plt.plot(history.history['val_loss'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# #### Matriz de confusion

# %%
prediction = model.predict(np.array(X_test))
y_test_matrix = [np.argmax(t) for t in y_test]
y_prediction_matrix = [np.argmax(t) for t in prediction]
confusion = confusion_matrix(y_test_matrix,y_prediction_matrix)

# %%
sns.heatmap(confusion,annot=True,fmt="d",cbar=False)
plt.show()

# %% [markdown]
# #### Guardamos el modelo

# %%
#model.save('dataset_model_binary.h5')

# %% [markdown]
# #### Cargamos el modelo

# %%
modelo_tr = load_model('dataset_model_binary.h5')

# %% [markdown]
# ### Prueba en imagenes individuales

# %%
x = 420
plt.imshow(X_test[x],cmap='gray')
predictImg(modelo_tr,X_test[x])
# Out:
# [[0.00648054 0.00116223 0.9996373 ]]
# [[0.006 0.001 1.   ]]

# %%
k = 140
plt.imshow(X_test[k],cmap='gray')
predictImg(modelo_tr,X_test[k])
# Out:
# [[0.9560647  0.03876999 0.31421423]]
# [[0.956 0.039 0.314]]

# %%
q = 96
plt.imshow(X_test[q],cmap='gray')
predictImg(modelo_tr,X_test[q])
# Out:
# [[3.6578211e-05 2.1562111e-01 9.9989450e-01]]
# [[0.    0.216 1.   ]]

# %%
q = 141
plt.imshow(X_test[q],cmap='gray')
predictImg(modelo_tr,X_test[q])
# Out:
# [[0.0249908  0.99193656 0.32402283]]
# [[0.025 0.992 0.324]]

# %%
q = 233
plt.imshow(X_test[q],cmap='gray')
predictImg(modelo_tr,X_test[q])
# Out:
# [[0.8130561  0.9090996  0.01915935]]
# [[0.813 0.909 0.019]]

# %% [markdown]
# ### problema #1 solucion a la binarizacion de una imagen de fondo no controlado

# %%
p1_img = test_images[3]

# %%
p1_img_test = generateImageGray(p1_img)

# %%
predictImg(modelo_tr,resShapeConv(p1_img_test))
# Out:
# [[0.53651166 0.9880676  0.0154101 ]]
# [[0.537 0.988 0.015]]

# %%
plt.imshow(p1_img)

# %%
cut_img = GrabCut(p1_img,200,20,370,780)

# %%
img_Bwhite = whiteBackground(cut_img)

# %%
img_gray = convertImageToGray(img_Bwhite)

# %%
th_img = thGaussOtsu(img_gray)

# %%
plt.imshow(th_img,cmap="gray")

# %%
th_img = generateSize(th_img)
plt.imshow(th_img,cmap="gray")

# %%
predictImg(modelo_tr,resShapeConv(th_img))
# Out:
# [[0.9999559  0.04003397 0.00171223]]
# [[1.    0.04  0.002]]

# %% [markdown]
# ### problema #2 solucion del fondo no controlado de la imagen del dataset

# %%
q = 233
img_p2 = X_test[q]
plt.imshow(img_p2,cmap='gray')
predictImg(modelo_tr,img_p2)
# Out:
# [[0.8130561  0.9090996  0.01915935]]
# [[0.813 0.909 0.019]]

# %%
img_th = cv2.adaptiveThreshold(img_p2,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)
plt.imshow(img_th,cmap = 'gray')

# %%
predictImg(modelo_tr,resShapeConv(img_th))
# Out:
# [[0.9984523  0.40270364 0.0306462 ]]
# [[0.998 0.403 0.031]]
